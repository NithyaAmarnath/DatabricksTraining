-- %%
grant privilege on object object_name to users

revoke privilege on object object_name from users

-- %%
show grants on catalog dev_na

-- %%
revoke all privileges on catalog dev from `account users`

-- %%
grant use catalog on catalog lakehouse to `account users`

-- %%
grant use schema on schema lakehouse.naval_bronze to `account users`

-- %%
create table lakehouse.naval_silver.sales_customers as 
select * from samples.bakehouse.sales_customers

-- %%
select * from lakehouse.naval_gold.sales_redacted
