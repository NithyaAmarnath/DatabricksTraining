-- %%
create function function_name (para datatype)
returns datatype
return logic business

-- %%
create function dev.default.full_name(first_name string, last_name string)
returns string
return concat(first_name, ' ', last_name)
