# %%
delta internals

# %%
# %sql
use catalog lakehouse;

# %%
# %sql
create schema lakehouse.nithya managed location 'abfss://raw@adlsnaval123.dfs.core.windows.net/lakehouse/nithya'

# %%
# %sql
create table lakehouse.nithya.demo (id int, name string)
